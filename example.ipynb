# %%
from feature_shap import  (
    FeatureSHAP, HuggingFaceModel, BlocksSplitter, RemovalModifier, BertScoreComparator, OllamaModel
)

# %%
# Initialize FeatureSHAP with the model, splitter, modifier, comparator, and custom instruction
fs = FeatureSHAP(
    # model=HuggingFaceModel("Qwen/Qwen2.5-Coder-0.5B-Instruct"),
    model=OllamaModel("gemma3:12b", base_url="http://host.docker.internal:11434/v1"),
    splitter=BlocksSplitter(language="python"),
    modifier=RemovalModifier(),
    comparator=BertScoreComparator(),
    instruction='\nWrite a single sentence summary of the code above.'
)

# %%
# Define the input
input = """
def read_files(files):
    content = ""
    for file in files:
        with open(file, 'r') as f:
            content += f.read()
    return content
""".lstrip()

# %%
# Compute the Shapley values
shapley_values, interactions = fs.analyze(input, sampling_ratio=1.0)
# Out:
# Batch generation: 100%|██████████| 1/1 [00:55<00:00, 55.48s/it]
# ['This code reads the content of multiple files and concatenates them into a single string.', 'The code reads the content of multiple files specified in the `files` list and concatenates them into a single string.', 'The code defines a function `read_files` that currently initializes an empty string and returns it, effectively doing nothing with the provided list of files.', 'The code reads the content of multiple files and concatenates them into a single string.', "The code defines a function `read_files` that is intended to read the content of a list of files, but it's incomplete as it doesn't actually perform the file reading operation and simply returns a variable named `content` which is not defined.", 'This code reads the content of each file in the `files` list and concatenates it into a single string called `content`.', 'The code reads the content of each file listed in the `files` input and concatenates it into the `content` variable.', 'The code initializes an empty string variable named `content`.', 'The code defines a function called `read_files` that presumably takes a list of files as input, although its functionality is not yet implemented.', 'The code initializes an empty string variable named `content` which will likely be used to store the combined content of multiple files.', 'The code defines a function that returns an empty string.', 'This code iterates through a list of files, opens each one in read mode, reads its entire content, and appends that content to a string variable named `content`.', 'This code reads the entire content of each file in a list of filenames and concatenates it into a single string.', 'The code returns the value stored in the variable named "content".']
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import pandas as pd

pd.DataFrame(
    [(k, float(v)) for k, v in shapley_values.items()],
    columns=["Feature", "Shapley Value"],
)
# Out:
#                                              Feature  Shapley Value
# 0                      def read_files(files):\n    1       0.000000
# 1                                content = ""\n    2       0.157755
# 2  for file in files:\n        with open(file, 'r...       0.760581
# 3                                  return content\n4       0.081664

# %%
interactions
# Out:
#                                                Prompt  \
# 0   content = ""\n    for file in files:\n        ...
# 1                                            def read
# 2                                            def read
# 3                                            def read
# 4                                            def read
# 5   content = ""\n    for file in files:\n        ...
# 6                                            def read
# 7                                  content = ""\n
# 8                                            def read
# 9                                            def read
# 10                 content = ""\n    return content\n
# 11  for file in files:\n        with open(file, 'r...
# 12  for file in files:\n        with open(file, 'r...
# 13                                   return content\n
#
#                                              Response Feature_Indexes  \
# 0   This code reads the content of multiple files ...       (2, 3, 4)
# 1   The code reads the content of multiple files s...       (1, 3, 4)
# 2   The code defines a function `read_files` that ...       (1, 2, 4)
# 3   The code reads the content of multiple files a...       (1, 2, 3)
# 4   The code defines a function `read_files` that ...          (1, 4)
# 5   This code reads the content of each file in th...          (2, 3)
# 6   The code reads the content of each file listed...          (1, 3)
# 7   The code initializes an empty string variable ...            (2,)
# 8   The code defines a function called `read_files...            (1,)
# 9   The code initializes an empty string variable ...          (1, 2)
# 10  The code defines a function that returns an em...          (2, 4)
# 11  This code iterates through a list of files, op...            (3,)
# 12  This code reads the entire content of each fil...          (3, 4)
# 13  The code returns the value stored in the varia...            (4,)
#
#     Similarity                                           Baseline
# 0     0.999820  The code reads the content of multiple files a...
# 1     0.973643  The code reads the content of multiple files a...
# 2     0.886974  The code reads the content of multiple files a...
# 3     1.000000  The code reads the content of multiple files a...
# 4     0.881781  The code reads the content of multiple files a...
# 5     0.947834  The code reads the content of multiple files a...
# 6     0.934817  The code reads the content of multiple files a...
# 7     0.878782  The code reads the content of multiple files a...
# 8     0.883789  The code reads the content of multiple files a...
# 9     0.901404  The code reads the content of multiple files a...
# 10    0.902481  The code reads the content of multiple files a...
# 11    0.906610  The code reads the content of multiple files a...
# 12    0.964309  The code reads the content of multiple files a...
# 13    0.881813  The code reads the content of multiple files a...
